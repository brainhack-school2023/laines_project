# %%
from nilearn import image
from nilearn import plotting
import nibabel as nib
from nilearn.plotting import view_img, plot_glass_brain, plot_anat, plot_epi
# Out:
# /home/nlaines/anaconda3/lib/python3.7/site-packages/nilearn/__init__.py:67: FutureWarning: Python 3.7 support is deprecated and will be removed in release 0.12 of Nilearn. Consider switching to Python 3.9 or 3.10.
#   _python_deprecation_warnings()

# %%
anat_masked=nib.load("/mnt/d/crmbm/DATABASE_MS_lesion_7T_iso_aniso/test_seg_canproco/7T_aniso_crop_masked_res.nii.gz")
lesion_masked=nib.load("/mnt/d/Poly/7T/ms_lesion_T1q_UNI_sub-00-ses-M0_T1q_000.nii.gz")

# %%
a=view_img(lesion_masked,anat_masked,annotate=False, resampling_interpolation="continuous", 
         cut_coords=None,colorbar=False, vmax=4 )
# Out:
# /home/nlaines/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:755: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/nlaines/anaconda3/lib/python3.7/site-packages/nilearn/image/resampling.py:295: UserWarning: Resampling binary images with continuous or linear interpolation. This might lead to unexpected results. You might consider using nearest interpolation instead.
#   "Resampling binary images with continuous or "

# %%
a
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
# ...

# %%
a.open_in_browser()  
a.save_as_html('sc_MP2RAGE_7T.html')

# %%
anat_masked=nib.load("/mnt/d/crmbm/data_sep_3T/sub00/t1q_crop_5_masked.nii.gz")
lesion_masked=nib.load("/mnt/d/Poly/brainhack_nnunet_test/test_T1q_UNI_proba/ms_lesion_T1q_UNI_sub-00-ses-M0_T1q_000.nii.gz")

# %%
a=view_img(lesion_masked,anat_masked,annotate=False, resampling_interpolation="continuous", 
         cut_coords=None,colorbar=False, vmax=4 )
# Out:
# /home/nlaines/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:755: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/nlaines/anaconda3/lib/python3.7/site-packages/nilearn/image/resampling.py:295: UserWarning: Resampling binary images with continuous or linear interpolation. This might lead to unexpected results. You might consider using nearest interpolation instead.
#   "Resampling binary images with continuous or "

# %%
a
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
# ...

# %%
a.open_in_browser()  
a.save_as_html('sc_MP2RAGE.html')

# %%
anat_masked=nib.load("/mnt/d/Poly/brainhack_nnunet_test/imagesTs_STIR_PSIR/ms_lesion_PSIR_STIR_sub-tor064-ses-M0_PSIR_047_0000.nii.gz")
lesion_masked=nib.load("/mnt/d/Poly/brainhack_nnunet_test/test_STIR_PSIR/ms_lesion_PSIR_STIR_sub-tor064-ses-M0_PSIR_047.nii.gz")
#concat=('/mnt/d/Poly/ms_lesion_PSIR_STIR_sub-mon174-ses-M0_PSIR_040_concat.nii.gz')

# %%
a=view_img(lesion_masked,anat_masked,annotate=False, resampling_interpolation="continuous", 
         cut_coords=None,colorbar=False, vmax=4 )
# Out:
# /home/nlaines/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:755: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   a.partition(kth, axis=axis, kind=kind, order=order)
# /home/nlaines/anaconda3/lib/python3.7/site-packages/nilearn/image/resampling.py:295: UserWarning: Resampling binary images with continuous or linear interpolation. This might lead to unexpected results. You might consider using nearest interpolation instead.
#   "Resampling binary images with continuous or "

# %%
a
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;title&gt;Slice viewer&lt;/title&gt;
#     &lt;meta charset=&quot;UTF-8&quot; /&gt;
# &lt;/head&gt;
# &lt;body&gt;
#   &lt;div id=&quot;div_viewer&quot;&gt;
#     &lt;!-- this is the canvas that will feature the brain slices --&gt;
#     &lt;canvas id=&quot;3Dviewer&quot;&gt;
#     &lt;!-- load a hidden version of the sprite image that includes all (sagittal) brain slices --&gt;
#     &lt;img id=&quot;spriteImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;background&quot; /&gt;
#     &lt;!-- the colormap --&gt;
#     &lt;img id=&quot;colorMap&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,&quot; alt=&quot;colormap&quot;&gt;
#     &lt;!-- another sprite image, with an overlay--&gt;
#     &lt;img id=&quot;overlayImg&quot; class=&quot;hidden&quot; src=&quot;data:image/png;base64,...&quot; alt=&quot;overlay&quot;&gt;
#     &lt;/canvas&gt;
# ...

# %%
a.open_in_browser()  
a.save_as_html('viewer.html')
